# %%
import pandas as pd

# %%
DF = "https://www.moneycontrol.com/financials/tatamotors/consolidated-balance-sheetVI/TM03#TM03"
df = pd.read_html(DF)
df1 = df[0]
df1

df1.to_excel("C:/Users/Admin/Downloads/BalanceSheet.xlsx")
df1
# Out:
#                                               0          1          2  \
# 0     Balance Sheet of Tata Motors (in Rs. Cr.)     Mar 23     Mar 22
# 1                                           NaN    12 mths    12 mths
# 2                      EQUITIES AND LIABILITIES        NaN        NaN
# 3                           SHAREHOLDER'S FUNDS        NaN        NaN
# 4                          Equity Share Capital     766.02     765.88
# 5                           Total Share Capital     766.02     765.88
# 6                          Reserves and Surplus   44553.31   43788.97
# 7                    Total Reserves and Surplus   44553.31   43788.97
# 8                      Total Shareholders Funds   45319.33   44554.85
# 9                             Minority Interest    7277.72    4271.06
# 10                      NON-CURRENT LIABILITIES        NaN        NaN
# 11                         Long Term Borrowings   88695.81   97759.17
# ...

# %%
df1.columns = df1.iloc[0]
df1.drop(df1.index[0],inplace=True)
df1
# Out:
# 0     Balance Sheet of Tata Motors (in Rs. Cr.)     Mar 23     Mar 22  \
# 1                                           NaN    12 mths    12 mths
# 2                      EQUITIES AND LIABILITIES        NaN        NaN
# 3                           SHAREHOLDER'S FUNDS        NaN        NaN
# 4                          Equity Share Capital     766.02     765.88
# 5                           Total Share Capital     766.02     765.88
# 6                          Reserves and Surplus   44553.31   43788.97
# 7                    Total Reserves and Surplus   44553.31   43788.97
# 8                      Total Shareholders Funds   45319.33   44554.85
# 9                             Minority Interest    7277.72    4271.06
# 10                      NON-CURRENT LIABILITIES        NaN        NaN
# 11                         Long Term Borrowings   88695.81   97759.17
# 12               Deferred Tax Liabilities [Net]    1406.95    1558.44
# ...

# %%
rows,columns = df1.shape
print("Number of rows in BalanceSheet :" , rows)
print("Number of columns in BalanceSheet :" , columns)
# Out:
# Number of rows in BalanceSheet : 53
# Number of columns in BalanceSheet : 7

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame
