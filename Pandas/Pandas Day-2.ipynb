# %% [markdown]
# # Head & Tail Functions in Pandas
#
# the head() and tail() functions are used to view a specified number of rows from the beginning or end of a DataFrame. These functions are helpful for quickly inspecting the data to get a sense of its structure and contents.

# %%
import pandas as pd

df = pd.read_csv("C:/Users/Vishal/Desktop/Data/CarSalesData.csv")

#head : --. it will return 1st five value in the table
df.head()

df.head(2)
# Out:
#    ClientID   ClientName          Address1  Address2       Town  County  \
# 0         1  Aldo Motors   4, Scale Street       NaN  Uttoxeter  Staffs
# 1         2  Honest John  99a Baker Street       NaN     London     NaN
#
#     PostCode                    Region OuterPostode  CountryID  ClientType  \
# 0  ST17 99RZ             East Midlands           ST          1  Wholesaler
# 1    NSW1 1A  Greater London Authority           EC          1      Dealer
#
#   ClientSize       ClientSince  IsCreditWorthy  IsDealer
# 0      Large  04-01-1998 00:00               1         1
# 1      Large  01-01-2000 00:00               0         0

# %%
#tail : --. it will return last five value in the table

df.tail()

df.tail(2)
# Out:
#     ClientID                      ClientName            Address1  Address2  \
# 29        30  British Luxury Automobile Corp  2555 Meridian Blvd       NaN
# 30        31                Classy Car Sales      30 Isabella St       NaN
#
#           Town        County PostCode Region OuterPostode  CountryID  \
# 29    Franklin      Tennesee      NaN    NaN           TN          3
# 30  Pittsburgh  Pennsylvania      NaN    NaN           PA          3
#
#     ClientType ClientSize ClientSince  IsCreditWorthy  IsDealer
# 29      Dealer      Large  04-01-2013               1         1
# 30  Wholesaler      Small  04-01-2013               1         0

# %% [markdown]
# # Describe Functions in Pandas
#
# In Pandas, the describe() function is a powerful tool for generating summary statistics of a DataFrame or Series. It provides a quick overview of the central tendency, dispersion, and shape of a dataset's distribution, excluding NaN values
#
# The statistics provided by describe() include:
#
# Count: Number of non-null entries in each column.
#
# Mean: Arithmetic mean (average) of the values.
#
# Std: Standard deviation, which measures the spread or dispersion of the data.
#
# Min: Minimum value in the column.
#
# 25%: 25th percentile value (Q1), which is the value below which 25% of the data falls.
#
# 50%: 50th percentile value (Q2 or median), which is the middle value of the dataset.
#
# 75%: 75th percentile value (Q3), which is the value below which 75% of the data falls.
#
# Max: Maximum value in the column.

# %%
student_marks = {
    "ID":[1,2,3,4],
    "Name":["Vishal","Ajay","Nita","Govind"],
    "Math":[25,28,21,26],
    "phys":[20,27,21,29],
    "Bio":[19,25,22,21],
    "Chem":[22,24,25,23],
}

df1 = pd.DataFrame(student_marks)
df1.describe()

#df.describe()
df1
# Out:
#    ID    Name  Math  phys  Bio  Chem
# 0   1  Vishal    25    20   19    22
# 1   2    Ajay    28    27   25    24
# 2   3    Nita    21    21   22    25
# 3   4  Govind    26    29   21    23

# %% [markdown]
# # In Pandas the df.info() and df.shape
#
# df.info():
#
# This function provides a summary of the DataFrame's structure and content. It displays information such as the number of non-null entries, data types of each column, memory usage, and more.
#
#
# df.shape:
#
# This attribute returns a tuple representing the dimensions of the DataFrame, which are the number of rows and columns, respectively

# %%
df1.info()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      4 non-null      int64
#  1   Name    4 non-null      object
#  2   Math    4 non-null      int64
#  3   phys    4 non-null      int64
#  4   Bio     4 non-null      int64
#  5   Chem    4 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 324.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ClientID        31 non-null     int64
#  1   ClientName      31 non-null     object
#  2   Address1        18 non-null     object
#  3   Address2        0 non-null      float64
#  4   Town            31 non-null     object
#  5   County          12 non-null     object
#  6   PostCode        15 non-null     object
#  7   Region          10 non-null     object
#  8   OuterPostode    20 non-null     object
#  9   CountryID       31 non-null     int64
#  10  ClientType      31 non-null     object
#  11  ClientSize      26 non-null     object
#  12  ClientSince     31 non-null     object
#  13  IsCreditWorthy  31 non-null     int64
#  14  IsDealer        31 non-null     int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 3.8+ KB

# %%
rows,columns = df.shape

print("Number of Rows in Car sales Data : " , rows)
print("Number of Columns in Car sales Data : " , columns)

print()

r , c = df1.shape

print("Number of Rows in Studnet marks Data : " , r)
print("Number of Columns in Studnet marks Data : " , c)
# Out:
# Number of Rows in Car sales Data :  31
# Number of Columns in Car sales Data :  15
#
# Number of Rows in Studnet marks Data :  4
# Number of Columns in Studnet marks Data :  6

# %% [markdown]
# # Featching row & column in pandas
#
# Column Featching
#
# 1.df['col_name']
#
# 2.type(df['col_name'])
#
# 3.Multiple coln in Data Frame : df[['col1','col2','col3']]
#
#
# Row Featching
#
# 1.df.iloc[index_value]
#
# 2.Multiple Row : df.iloc[r1:r5]
#
# 3.Specific Row : df.iloc[r1,r2,r3]

# %%
#Column Featching

df['ClientName'] #single column at a time

df #ClientName / County /Town / Region

df[['ClientName','County','Town','Region']]#Multiple column at a time
# Out:
#                         ClientName        County                 Town  \
# 0                      Aldo Motors        Staffs            Uttoxeter
# 1                      Honest John           NaN               London
# 2                    Bright Orange           NaN           Birmingham
# 3                       Cut'n'Shut           NaN           Manchester
# 4                      Wheels'R'Us           NaN               London
# 5                   Les Arnaqueurs           NaN                Paris
# 6                     Crippen & Co           NaN              Glasgow
# 7                     Rocky Riding      New York             New York
# 8      Voitures Diplomatiques S.A.           NaN               Geneva
# 9                             Karz           NaN            Stuttgart
# 10                 Costa Del Speed           NaN               Madrid
# 11                   Olde Englande           NaN           Shrewsbury
# 12               Impressive Wheels           NaN            Liverpool
# 13                   Smooth Riders           NaN              Telford
# 14                  Luxury Rentals           NaN           Gloucester
# 15          Premium Motor Vehicles           NaN  Newcastle upon Tyne
# 16                     Chateau Moi           NaN                 Lyon
# 17                Vive la Vitesse!           NaN            Marseille
# 18               Carosse Des Papes           NaN              Avignon
# 19              Three Country Cars           NaN                Basle
# 20                        Jungfrau           NaN               Zurich
# 21                 Ambassador Cars    Washington             Bellevue
# 22                  Embassy Motors      Colorado               Denver
# 23                   Style ‘N Ride      Maryland          Chevy Chase
# 24                      BritWheels        Oregon             Portland
# 25               Sporty Types Corp    California        San Francisco
# 26                   Tweedy Wheels  Massahussets            Cambridge
# 27          Union Jack Sports Cars      Kentucky           Louisville
# 28  Buckingham Palace Car Services          Ohio                Mason
# 29  British Luxury Automobile Corp      Tennesee             Franklin
# 30                Classy Car Sales  Pennsylvania           Pittsburgh
#
#                       Region
# 0              East Midlands
# 1   Greater London Authority
# 2              West Midlands
# 3                 North West
# 4   Greater London Authority
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                       NaN
# 11             West Midlands
# 12                North West
# 13             West Midlands
# 14                South West
# 15                North East
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# 30                       NaN

# %%
#Row Featching

df.iloc[0] #Single row at a time

df.iloc[5:15] #specific range or rows

df.iloc[[1,10,15,30]]#specific index
# Out:
#     ClientID              ClientName          Address1  Address2  \
# 1          2             Honest John  99a Baker Street       NaN
# 10        11         Costa Del Speed               NaN       NaN
# 15        16  Premium Motor Vehicles               NaN       NaN
# 30        31        Classy Car Sales    30 Isabella St       NaN
#
#                    Town        County PostCode                    Region  \
# 1                London           NaN  NSW1 1A  Greater London Authority
# 10               Madrid           NaN      NaN                       NaN
# 15  Newcastle upon Tyne           NaN  NE3 3SS                North East
# 30           Pittsburgh  Pennsylvania      NaN                       NaN
#
#    OuterPostode  CountryID  ClientType ClientSize       ClientSince  \
# 1            EC          1      Dealer      Large  01-01-2000 00:00
# 10          NaN          5      Dealer      Small  31-05-2012 00:00
# 15           NE          1      Dealer      Small  31-05-2009 00:00
# 30           PA          3  Wholesaler      Small        04-01-2013
#
#     IsCreditWorthy  IsDealer
# 1                0         0
# 10               1         0
# 15               1         0
# 30               1         0
