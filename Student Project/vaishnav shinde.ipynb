# %% [markdown]
# ![Who-is-the-owner-of-Mahindra-Mahindra-Ltd-Wiki-Logo.jpg](attachment:Who-is-the-owner-of-Mahindra-Mahindra-Ltd-Wiki-Logo.jpg)

# %%
import pandas as pd

# %%
df = "https://economictimes.indiatimes.com/mahindra-mahindra-ltd/balancesheet/companyid-11898.cms"
df =pd.read_html(df)
df1 = df[0]

data = df1.transpose()

data.to_csv("C:/Users/Vishal/Desktop/Data/MM.csv")

# %%
df = pd.read_csv("C:/Users/Vishal/Desktop/Data/MM.csv")

df
# Out:
#   Particulars  Share Capital  Reserves & Surplus  Net Worth  Secured Loan  \
# 0      Mar'23         859.38            42497.35   43356.73       4643.73
# 1      Mar'22         821.76            38139.19   38960.95       6489.95
# 2      Mar'21         852.27            33649.65   34501.92       7094.77
# 3      Mar'20         861.48            33606.36   34467.84       2932.03
# 4      Mar'19         595.80            33613.43   34209.23       2480.32
#
#    TOTAL LIABILITIES  Gross Block  (-) Acc. Depreciation  Net Block  \
# 0           48000.46     31896.31               14920.11   16976.20
# 1           45450.90     27632.55               13083.93   14548.62
# 2           41596.69     20856.52               10677.17   10179.35
# 3           37399.87     20000.25                9605.66   10394.59
# 4           36689.55     18534.97                8453.22   10081.75
#
#    Capital Work in Progress  ...  Inventories  Sundry Debtors  Cash and Bank  \
# ...

# %%
print("Average net worth of Mahindra & Mahindra btw year 2019 & 2023 : " ,df['Net Worth'].mean() )
# Out:
# Average net worth of Mahindra & Mahindra btw year 2019 & 2023 :  37099.334

# %%
# Out:
#                                           0  \
# 0   BalanceSheet - Mahindra & Mahindra Ltd.
# 1                            Rs (in Crores)
# 2                               Particulars
# 3                               Liabilities
# 4                             Share Capital
# 5                        Reserves & Surplus
# 6                                 Net Worth
# 7                              Secured Loan
# 8                            Unsecured Loan
# 9                         TOTAL LIABILITIES
# 10                                   Assets
# 11                              Gross Block
# 12                    (-) Acc. Depreciation
# 13                                Net Block
# 14                 Capital Work in Progress
# 15                              Investments
# 16                              Inventories
# 17                           Sundry Debtors
# 18                            Cash and Bank
# 19                       Loans and Advances
# ...

# %%
df['TOTAL ASSETS(A+B+C+D+E)']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['TOTAL ASSETS(A+B+C+D+E)']
#
# NameError: name 'df' is not defined
