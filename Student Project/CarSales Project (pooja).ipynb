# %%
import pandas as pd

# %%
"""
This Function will return Number particular Data from the Data Base

"""

def get_count(coln,info):
    data = df[coln] == info
    return df[data].shape[0]

# %%
df = pd.read_excel("C:/Users/Admin/Documents/paython/PANDAS/CarSales.xlsx")
df.drop(['IsDealer'], axis=1, inplace=True)
df
# Out:
#     InvoiceDate          Make     CountryName  SalePrice  CostPrice  \
# 0    2012-10-04   Rolls Royce  United Kingdom      95000      50000
# 1    2012-01-01  Aston Martin  United Kingdom     120000      75000
# 2    2012-02-02   Rolls Royce  United Kingdom      88000      75000
# 3    2012-03-03   Rolls Royce  United Kingdom      89000      88000
# 4    2012-04-04   Rolls Royce  United Kingdom      92000      62000
# ..          ...           ...             ...        ...        ...
# 452  2015-09-23  Aston Martin             USA      39750      27500
# 453  2015-10-24  Aston Martin             USA      40440      22500
# 454  2015-11-25   Rolls Royce             USA      72000      22500
# 455  2015-11-26  Aston Martin             USA      40440      36125
# 456  2015-11-27  Aston Martin             USA      77250      22500
#
#      TotalDiscount  DeliveryCharge  SpareParts  LaborCost  \
# 0            500.0             750         500        750
# ...

# %%
"""

"""

df.value_counts('Make').plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 """
#       2
#       3 """
# ----> 5 df.value_counts('Make').plot(kind="bar")
#
# NameError: name 'df' is not defined

# %%
d1 = df['CountryName'] == "France"
print("Number of cars sales in France:", df[d1].shape[0])

d2 = df['CountryName'] == "Germany"
print("Number of cars sales in Germany:", df[d2].shape[0])

d3 = df['CountryName'] == "Spain"
print("Number of cars sales in Spain:", df[d3].shape[0])

d4 = df['CountryName'] == "Switzerland"
print("Number of cars sales in Switzerland:", df[d4].shape[0])

d5 = df['CountryName'] == "United Kingdom"
print("Number of cars sales in United Kingdom:", df[d5].shape[0])

d6 = df['CountryName'] == "USA"
print("Number of cars sales in USA:", df[d6].shape[0])
# Out:
# Number of cars sales in France: 40
# Number of cars sales in Germany: 4
# Number of cars sales in Spain: 6
# Number of cars sales in Switzerland: 26
# Number of cars sales in United Kingdom: 215
# Number of cars sales in USA: 166

# %%
df.value_counts('Color')
# Out:
# Color
# Red                     83
# Canary Yellow           71
# Blue                    59
# Silver                  56
# Green                   41
# Black                   40
# British Racing Green    39
# Dark Purple             36
# Night Blue              32
# dtype: int64

# %%
df.value_counts('Make').plot(kind='pie')
# Out:
# <Axes: >

# %%
df.value_counts('CountryName').head(6).plot(kind='bar')
# Out:
# <Axes: xlabel='CountryName'>

# %%
df.head(2).plot(y=["SalePrice","CostPrice"],x="Make",kind="bar")
# Out:
# <Axes: xlabel='Make'>

# %%
d = df['Model'] == 'DBS'
print("number of DBS model :" ,df[d].shape[0])
# Out:
# number of DBS model : 4

# %%
df.shape
# Out:
# (457, 21)

# %%
print("minimum saleprice of cars :" , df['SalePrice'].min())
print("maximum saleprice of cars :" , df['SalePrice'].max())
# Out:
# minimum saleprice of cars : 22500
# maximum saleprice of cars : 181250

# %%
df.value_counts('Model')
# Out:
# Model
# XK               95
# DB9              54
# Continental      51
# Camargue         39
# GT               36
# XJ6              26
# TR4              22
# DB7              16
# Silver Ghost     12
# Vantage          12
# Tuscan           10
# Vanquish         10
# Turbo R          10
# XJ12              8
# Azure             8
# DB4               8
# TR5               8
# Silver Seraph     4
# TR7               4
# Silver Shadow     4
# DBS               4
# Cerbera           4
# Rapide            4
# Arnage            2
# Wraith            2
# Phantom           2
# Zagato            2
# dtype: int64

# %%
df.value_counts('Model').head(6).plot(kind='bar')
# Out:
# <Axes: xlabel='Model'>

# %%
def get_count(coln,info):
    data = df[coln] == info
    return df[data].shape[0]

# %%
print("Number of Red cars sales in data base:" , get_count("Color","Red"))
print("Number of Green cars sales in data base:" , get_count("Color","Green"))
print("Number of cars sales in 2012 :" , get_count("ReportingYear",2012))
print("Number of cars sales in 2015 :" , get_count("ReportingYear",2015))
# Out:
# Number of Red cars sales in data base: 83
# Number of Green cars sales in data base: 41
# Number of cars sales in 2012 : 39
# Number of cars sales in 2015 : 226

# %%
df['ClientName'].drop_duplicates()
# Out:
# 0                         Aldo Motors
# 1                         Honest John
# 2                       Bright Orange
# 4                         Wheels'R'Us
# 5                          Cut'n'Shut
# 7                      Les Arnaqueurs
# 39                       Rocky Riding
# 41        Voitures Diplomatiques S.A.
# 55                       Crippen & Co
# 87                    Costa Del Speed
# 88                               Karz
# 99                      Olde Englande
# 100                 Impressive Wheels
# 102                     Smooth Riders
# 103                    Luxury Rentals
# 104            Premium Motor Vehicles
# 135                       Chateau Moi
# 136                  Vive la Vitesse!
# 137                 Carosse Des Papes
# 138                Three Country Cars
# 139                          Jungfrau
# 307                   Ambassador Cars
# 309                    Embassy Motors
# 310                     Style ‘N Ride
# 312                 Sporty Types Corp
# ...

# %%
df['Model'].drop_duplicates()
# Out:
# 0           Camargue
# 1                DBS
# 2       Silver Ghost
# 7                DB7
# 8                DB9
# 10               DB4
# 11           Vantage
# 12          Vanquish
# 13            Rapide
# 14            Zagato
# 16            Wraith
# 19     Silver Shadow
# 20     Silver Seraph
# 26           Phantom
# 39                XK
# 40               XJ6
# 41              XJ12
# 63       Continental
# 64            Arnage
# 65             Azure
# 66           Turbo R
# 88            Tuscan
# 90           Cerbera
# 111               GT
# 123              TR4
# 124              TR5
# 125              TR7
# Name: Model, dtype: object

# %%
print("Total SalePrice of cars in data set: " ,df['SalePrice'].sum())

print("Total CostPrice of cars in data set: " ,df['CostPrice'].sum())

print("Total Average SalePrice of cars in data set: " ,df['SalePrice'].mean())
# Out:
# Total SalePrice of cars in data set:  31697940
# Total CostPrice of cars in data set:  20409895
# Total Average SalePrice of cars in data set:  69360.91903719913

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   InvoiceDate        457 non-null    datetime64[ns]
#  1   Make               457 non-null    object
#  2   CountryName        457 non-null    object
#  3   SalePrice          457 non-null    int64
#  4   CostPrice          457 non-null    int64
#  5   TotalDiscount      457 non-null    float64
#  6   DeliveryCharge     457 non-null    int64
#  7   SpareParts         457 non-null    int64
#  8   LaborCost          457 non-null    int64
#  9   ClientName         457 non-null    object
#  10  Model              457 non-null    object
#  11  Color              457 non-null    object
#  12  ReportingYear      457 non-null    int64
#  13  ReportingMonth     457 non-null    int64
#  14  Registration_Date  457 non-null    datetime64[ns]
# ...

# %%
g = df.groupby('Make')
g1 = df.groupby('CountryName')

# %%
g.get_group('TVR').head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 g.get_group('TVR').head(2)
#
# NameError: name 'g' is not defined

# %%
g.mean(numeric_only=True)
# Out:
#                   SalePrice     CostPrice  TotalDiscount  DeliveryCharge  \
# Make
# Aston Martin   97145.818182  60952.454545     763.136545      795.000000
# Bentley        69735.915493  44347.887324     660.563380      554.225352
# Jaguar         48984.496124  37982.170543     376.356589      360.658915
# MGB            28083.333333   9500.000000     187.500000       15.277778
# Rolls Royce   116776.190476  65336.904762     471.428571     1008.253968
# TVR            35625.000000  40714.285714     182.142857       12.500000
# Triumph        25735.294118  18485.294118     202.941176       70.588235
#
#                SpareParts   LaborCost  ReportingYear  ReportingMonth
# Make
# Aston Martin   813.454545  887.136364    2014.045455        6.672727
# Bentley       2255.633803  883.605634    2013.845070        6.577465
# Jaguar        1323.720930  574.279070    2014.054264        6.480620
# MGB            312.500000  325.000000    2014.333333        6.500000
# ...

# %%
g1.first()
# Out:
#                InvoiceDate          Make  SalePrice  CostPrice  TotalDiscount  \
# CountryName
# France          2012-07-04  Aston Martin     125000      23500         2500.0
# Germany         2013-02-02           TVR      41250      37500          150.0
# Spain           2013-01-02        Jaguar      29750      37500          150.0
# Switzerland     2012-03-01        Jaguar      39500      25000          500.0
# USA             2012-01-01        Jaguar      44000      25000          500.0
# United Kingdom  2012-10-04   Rolls Royce      95000      50000          500.0
#
#                 DeliveryCharge  SpareParts  LaborCost  \
# CountryName
# France                    1000         900        550
# Germany                     50         400        325
# Spain                       50         400        486
# Switzerland                  0        1950        486
# USA                        450        1950        486
# United Kingdom             750         500        750
#
# ...

# %%
g1.get_group('Spain')
# Out:
#     InvoiceDate     Make CountryName  SalePrice  CostPrice  TotalDiscount  \
# 87   2013-01-02   Jaguar       Spain      29750      37500          150.0
# 89   2013-03-02   Jaguar       Spain      39500      37500          150.0
# 128  2013-06-02  Triumph       Spain      22500      17000          150.0
# 240  2015-01-02  Bentley       Spain      46750      30700          200.0
# 242  2015-03-02      TVR       Spain      44000      42500          200.0
# 281  2015-06-02  Triumph       Spain      25250      13500          200.0
#
#      DeliveryCharge  SpareParts  LaborCost       ClientName    Model  \
# 87               50         400        486  Costa Del Speed       XK
# 89               50         400        325  Costa Del Speed       XK
# 128              50         250        325  Costa Del Speed      TR5
# 240              25        2570        486  Costa Del Speed  Turbo R
# 242              25         400        325  Costa Del Speed   Tuscan
# ...

# %%
A = df['Make'].drop_duplicates()
A
# Out:
# 0       Rolls Royce
# 1      Aston Martin
# 39           Jaguar
# 63          Bentley
# 88              TVR
# 111             MGB
# 123         Triumph
# Name: Make, dtype: object
